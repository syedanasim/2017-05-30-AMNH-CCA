# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as mpl

# %%
import matplotlib
# %matplotlib inline

# %%
# Let's create a function to model and create data
def func(x, a, x0, sigma):
    return a*np.exp(-(x-x0)**2/(2*sigma**2))

# %%
np.exp((1,2,5))
# Out:
# array([   2.71828183,    7.3890561 ,  148.4131591 ])

# %%
# Generating clean data
x = np.linspace(0, 10, 100)
y = func(x, 1, 5, 2)

# %%
# Adding noise to the data
yn = y + 0.2 * np.random.normal(size=len(x))

# %%
np.random.normal(size=(5,5)).shape
# Out:
# (5, 5)

# %%
# Plot out the current state of the data and model
fig = mpl.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, c='k', label='Function')
ax.scatter(x, yn)
fig.savefig('model_and_noise.png')

# %%
# Executing curve_fit on noisy data
popt, pcov = curve_fit(func, x, yn)

# %%
#popt returns the best fit values for parameters of the given model (func)
print (popt)
print (pcov)
# Out:
# [ 1.02193556  5.06156258 -1.88090316]
# [[  1.60754035e-03  -1.67933708e-06   1.99416654e-03]
#  [ -1.67933708e-06   7.24581289e-03  -7.26218438e-06]
#  [  1.99416654e-03  -7.26218438e-06   7.35736385e-03]]

# %%
fig = mpl.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, c='k', label='Function')
ax.scatter(x, yn)
fig.savefig('model_and_noise.png')

ym = func(x, popt[0], popt[1], popt[2])
ax.plot(x, ym, c='r', label='Best fit')
ax.legend()
fig.savefig('model_fit.png')

# %%
# Let's create a function to model and create data
def func(x, a, x0, sigma):
    return a*np.exp(-(x-x0)**2/(2*sigma**2))

# %%
# Generating clean data
x = np.linspace(0, 20, 200)
y1 = func(x[np.where(x <= 10)], 1, 3, 1)
y2 = func(x[np.where(x > 10)], -2, 15, 0.5)

# %%
y = np.hstack([y1, y2])

# %%
# Adding noise to the data
yn = y + 0.2 * np.random.normal(size=len(x))

# %%
# Plot out the current state of the data and model
fig = mpl.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, c='k', label='Function')
ax.scatter(x, yn)
fig.savefig('model_and_noise_multiple.png')

# %%
# Executing curve_fit on noisy data
popt, pcov = curve_fit(func, x, yn)

# %%
# Executing curve_fit on noisy data
popt, pcov = curve_fit(func, x, yn)

# %%
#popt returns the best fit values for parameters of the given model (func)
print (popt)
# Out:
# [ 1.01439452  3.03948901  0.9956352 ]

# %%
fig = mpl.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, c='k', label='Function')
ax.scatter(x, yn)
fig.savefig('model_and_noise_multiple.png')

ym = func(x, popt[0], popt[1], popt[2])
ax.plot(x, ym, c='r', label='Best fit')
ax.legend()
fig.savefig('model_fit_multiple.png')
